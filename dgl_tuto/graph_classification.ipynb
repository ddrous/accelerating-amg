# %%
import dgl
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import dgl.data

# Generate a synthetic dataset with 10000 graphs, ranging from 10 to 500 nodes.
dataset = dgl.data.GINDataset('PROTEINS', self_loop=True)

# %%
print('Node feature dimensionality:', dataset.dim_nfeats)
print('Number of graph categories:', dataset.gclasses)
# Out:
# Node feature dimensionality: 3
# Number of graph categories: 2

# %%
import graph_vis
print(dataset[0][0])
graph_vis.visualize(dataset[0][0], file_name='.\pyvis_exports\protein.html', nb_nodes_plot=None, notebook=False)
# Out:
# Graph(num_nodes=42, num_edges=204,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})

# %%
from dgl.dataloading import GraphDataLoader
from torch.utils.data.sampler import SubsetRandomSampler

num_examples = len(dataset)
num_train = int(num_examples * 0.8)

train_sampler = SubsetRandomSampler(torch.arange(num_train))
test_sampler = SubsetRandomSampler(torch.arange(num_train, num_examples))

train_dataloader = GraphDataLoader(
    dataset, sampler=train_sampler, batch_size=5, drop_last=False)
test_dataloader = GraphDataLoader(
    dataset, sampler=test_sampler, batch_size=5, drop_last=False)

# %%
it = iter(train_dataloader)
batch = next(it)
print(batch)
# Out:
# [Graph(num_nodes=244, num_edges=1144,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={}), tensor([0, 0, 0, 0, 1])]

# %%
batched_graph, labels = batch
print('Number of nodes for each graph element in the batch:', batched_graph.batch_num_nodes())
print('Number of edges for each graph element in the batch:', batched_graph.batch_num_edges())

# Recover the original graph elements from the minibatch
graphs = dgl.unbatch(batched_graph)
print('The original graphs in the minibatch:')
print(graphs)
# Out:
# Number of nodes for each graph element in the batch: tensor([ 43,  32,  20, 133,  16])
# Number of edges for each graph element in the batch: tensor([223, 150,  90, 593,  88])
# The original graphs in the minibatch:
# [Graph(num_nodes=43, num_edges=223,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={}), Graph(num_nodes=32, num_edges=150,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={}), Graph(num_nodes=20, num_edges=90,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={}), Graph(num_nodes=133, num_edges=593,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={}), Graph(num_nodes=16, num_edges=88,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})]

# %%
from dgl.nn import GraphConv

class GCN(nn.Module):
    def __init__(self, in_feats, h_feats, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GraphConv(in_feats, h_feats)
        self.conv2 = GraphConv(h_feats, num_classes)

    def forward(self, g, in_feat):
        # print("before:", g)
        h = self.conv1(g, in_feat)
        h = F.relu(h)
        h = self.conv2(g, h)
        g.ndata['h'] = h
        # print("after:", g)
        return dgl.mean_nodes(g, 'h')

# %%
# Create the model with given dimensions
model = GCN(dataset.dim_nfeats, 16, dataset.gclasses)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(1):
    for batched_graph, labels in train_dataloader:
        pred = model(batched_graph, batched_graph.ndata['attr'].float())
        loss = F.cross_entropy(pred, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

num_correct = 0
num_tests = 0
for batched_graph, labels in test_dataloader:
    pred = model(batched_graph, batched_graph.ndata['attr'].float())
    num_correct += (pred.argmax(1) == labels).sum().item()
    num_tests += len(labels)

print('Test accuracy:', num_correct / num_tests)
# Out:
# before: Graph(num_nodes=120, num_edges=604,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=120, num_edges=604,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=93, num_edges=481,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=93, num_edges=481,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=266, num_edges=1214,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=266, num_edges=1214,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=152, num_edges=734,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=152, num_edges=734,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=200, num_edges=930,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=200, num_edges=930,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=116, num_edges=610,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=116, num_edges=610,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=181, num_edges=885,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=181, num_edges=885,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=192, num_edges=966,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=192, num_edges=966,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=176, num_edges=862,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=176, num_edges=862,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=168, num_edges=842,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=168, num_edges=842,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=109, num_edges=507,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=109, num_edges=507,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=229, num_edges=1169,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=229, num_edges=1169,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=193, num_edges=855,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=193, num_edges=855,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=170, num_edges=798,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=170, num_edges=798,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=284, num_edges=1270,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=284, num_edges=1270,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=191, num_edges=861,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=191, num_edges=861,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=150, num_edges=680,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=150, num_edges=680,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=140, num_edges=634,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=140, num_edges=634,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=245, num_edges=1273,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=245, num_edges=1273,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=166, num_edges=840,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=166, num_edges=840,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=202, num_edges=954,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=202, num_edges=954,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=159, num_edges=787,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=159, num_edges=787,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=124, num_edges=568,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=124, num_edges=568,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=229, num_edges=1041,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=229, num_edges=1041,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=403, num_edges=2065,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=403, num_edges=2065,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=513, num_edges=2153,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=513, num_edges=2153,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=730, num_edges=3312,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=730, num_edges=3312,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=216, num_edges=910,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=216, num_edges=910,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=188, num_edges=954,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=188, num_edges=954,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=168, num_edges=788,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=168, num_edges=788,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=393, num_edges=1861,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=393, num_edges=1861,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=111, num_edges=523,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=111, num_edges=523,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=144, num_edges=628,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=144, num_edges=628,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=196, num_edges=1014,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=196, num_edges=1014,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=202, num_edges=964,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=202, num_edges=964,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=271, num_edges=1349,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=271, num_edges=1349,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=168, num_edges=786,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=168, num_edges=786,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=313, num_edges=1417,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=313, num_edges=1417,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=131, num_edges=637,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=131, num_edges=637,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=421, num_edges=1919,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=421, num_edges=1919,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=152, num_edges=732,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=152, num_edges=732,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=297, num_edges=1229,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=297, num_edges=1229,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=180, num_edges=826,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=180, num_edges=826,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=128, num_edges=612,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=128, num_edges=612,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=122, num_edges=652,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=122, num_edges=652,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=101, num_edges=481,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=101, num_edges=481,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=271, num_edges=1333,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=271, num_edges=1333,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=175, num_edges=757,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=175, num_edges=757,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=357, num_edges=1609,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=357, num_edges=1609,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=152, num_edges=724,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=152, num_edges=724,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=157, num_edges=701,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=157, num_edges=701,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=280, num_edges=1330,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=280, num_edges=1330,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=265, num_edges=1295,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=265, num_edges=1295,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=129, num_edges=609,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=129, num_edges=609,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=336, num_edges=1338,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=336, num_edges=1338,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=178, num_edges=892,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=178, num_edges=892,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=178, num_edges=762,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=178, num_edges=762,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=282, num_edges=1294,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=282, num_edges=1294,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=94, num_edges=452,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=94, num_edges=452,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=165, num_edges=793,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=165, num_edges=793,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=265, num_edges=1223,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=265, num_edges=1223,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=290, num_edges=1286,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=290, num_edges=1286,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=261, num_edges=1159,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=261, num_edges=1159,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=207, num_edges=1007,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=207, num_edges=1007,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=167, num_edges=761,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=167, num_edges=761,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=125, num_edges=593,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=125, num_edges=593,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=91, num_edges=417,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=91, num_edges=417,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=300, num_edges=1496,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=300, num_edges=1496,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=194, num_edges=928,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=194, num_edges=928,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=103, num_edges=519,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=103, num_edges=519,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=299, num_edges=1319,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=299, num_edges=1319,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=354, num_edges=1622,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=354, num_edges=1622,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=120, num_edges=530,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=120, num_edges=530,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=224, num_edges=1112,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=224, num_edges=1112,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=231, num_edges=1003,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=231, num_edges=1003,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=286, num_edges=1424,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=286, num_edges=1424,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=351, num_edges=1551,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=351, num_edges=1551,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=143, num_edges=689,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=143, num_edges=689,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=246, num_edges=1212,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=246, num_edges=1212,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=210, num_edges=1090,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=210, num_edges=1090,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=203, num_edges=935,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=203, num_edges=935,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=149, num_edges=729,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=149, num_edges=729,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=283, num_edges=1339,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=283, num_edges=1339,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=143, num_edges=697,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=143, num_edges=697,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=216, num_edges=1000,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=216, num_edges=1000,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=241, num_edges=1197,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=241, num_edges=1197,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=218, num_edges=1032,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=218, num_edges=1032,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=205, num_edges=1023,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=205, num_edges=1023,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=179, num_edges=865,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=179, num_edges=865,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=396, num_edges=1872,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=396, num_edges=1872,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=693, num_edges=3665,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=693, num_edges=3665,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=111, num_edges=525,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=111, num_edges=525,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=91, num_edges=411,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=91, num_edges=411,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=154, num_edges=756,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=154, num_edges=756,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=242, num_edges=1244,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=242, num_edges=1244,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=271, num_edges=1267,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=271, num_edges=1267,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=163, num_edges=749,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=163, num_edges=749,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=161, num_edges=803,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=161, num_edges=803,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=164, num_edges=782,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=164, num_edges=782,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=146, num_edges=708,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=146, num_edges=708,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=117, num_edges=551,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=117, num_edges=551,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=123, num_edges=585,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=123, num_edges=585,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=166, num_edges=772,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=166, num_edges=772,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=116, num_edges=546,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=116, num_edges=546,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=144, num_edges=656,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=144, num_edges=656,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=215, num_edges=975,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=215, num_edges=975,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=127, num_edges=621,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=127, num_edges=621,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=205, num_edges=1033,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=205, num_edges=1033,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=668, num_edges=3018,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=668, num_edges=3018,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=293, num_edges=1369,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=293, num_edges=1369,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=176, num_edges=958,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=176, num_edges=958,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=125, num_edges=603,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=125, num_edges=603,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=171, num_edges=821,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=171, num_edges=821,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=178, num_edges=836,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=178, num_edges=836,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=296, num_edges=1376,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=296, num_edges=1376,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=140, num_edges=644,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=140, num_edges=644,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# ...
#       edata_schemes={})
# after: Graph(num_nodes=160, num_edges=824,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=33, num_edges=155,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=33, num_edges=155,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=62, num_edges=308,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=62, num_edges=308,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=144, num_edges=642,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=144, num_edges=642,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=87, num_edges=399,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=87, num_edges=399,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=64, num_edges=308,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=64, num_edges=308,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=163, num_edges=723,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=163, num_edges=723,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=119, num_edges=525,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=119, num_edges=525,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=109, num_edges=493,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=109, num_edges=493,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=90, num_edges=432,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=90, num_edges=432,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=68, num_edges=318,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=68, num_edges=318,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=62, num_edges=298,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=62, num_edges=298,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=71, num_edges=335,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=71, num_edges=335,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=62, num_edges=296,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=62, num_edges=296,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=82, num_edges=368,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=82, num_edges=368,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=70, num_edges=314,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=70, num_edges=314,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=168, num_edges=804,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=168, num_edges=804,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=134, num_edges=606,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=134, num_edges=606,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=151, num_edges=729,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=151, num_edges=729,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=128, num_edges=538,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=128, num_edges=538,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=137, num_edges=621,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=137, num_edges=621,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=73, num_edges=349,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=73, num_edges=349,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=107, num_edges=527,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=107, num_edges=527,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=49, num_edges=237,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=49, num_edges=237,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=122, num_edges=632,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=122, num_edges=632,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=89, num_edges=381,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=89, num_edges=381,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=60, num_edges=254,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=60, num_edges=254,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=121, num_edges=517,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=121, num_edges=517,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=49, num_edges=233,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=49, num_edges=233,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=65, num_edges=307,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=65, num_edges=307,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=78, num_edges=376,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=78, num_edges=376,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=105, num_edges=499,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=105, num_edges=499,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=99, num_edges=463,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=99, num_edges=463,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=107, num_edges=445,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=107, num_edges=445,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=215, num_edges=1023,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=215, num_edges=1023,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=63, num_edges=279,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=63, num_edges=279,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=86, num_edges=404,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=86, num_edges=404,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=205, num_edges=981,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=205, num_edges=981,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# before: Graph(num_nodes=73, num_edges=321,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32)}
#       edata_schemes={})
# after: Graph(num_nodes=73, num_edges=321,
#       ndata_schemes={'label': Scheme(shape=(), dtype=torch.int64), 'attr': Scheme(shape=(3,), dtype=torch.float32), 'h': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# Test accuracy: 0.0
